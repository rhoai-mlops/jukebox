# %% [markdown]
# You can download the dataset from here: https://www.kaggle.com/datasets/asaniczka/top-spotify-songs-in-73-countries-daily-updated/data

# %%
import pandas as pd

# %%
data = pd.read_csv('universal_top_spotify_songs.csv')
data
# Out:
#                    spotify_id  \
# 0      2plbrEY59IikOBgBGLjaoe
# 1      6dOtVTDdiauQNBQEDOtlAB
# 2      7tI8dRuH2Yc6RuoTjxo4dU
# 3      5N3hjp1WNayUPZrA8kJmJP
# 4      2qSkIjg1o9h3YT9RAgYN75
# ...                       ...
# 17779  7fveJ3pk1eSfxBdVkzdXZ0
# 17780  4pkb8SbRGeHAvdb87v9rpf
# 17781  5iJKGpnFfvbjZJeAtwXfCj
# 17782  51eSHglvG1RJXtL3qI5trr
# 17783  62bOmKYxYg7dhrC6gH9vFn
#
#                                                     name  \
# 0                                       Die With A Smile
# 1                                     BIRDS OF A FEATHER
# 2                                                    Who
# 3                                   Please Please Please
# 4                                               Espresso
# ...                                                  ...
# 17779                            Cowgirls (feat. ERNEST)
# 17780                                        Miles On It
# 17781                                                 28
# 17782                                       Slow It Down
# 17783  Bye Bye Bye - From Deadpool and Wolverine Soun...
#
#                       artists  daily_rank  daily_movement  weekly_movement  \
# 0       Lady Gaga, Bruno Mars           1               1                6
# 1               Billie Eilish           2              -1                0
# 2                       Jimin           3               2               -2
# 3           Sabrina Carpenter           4              -1                0
# 4           Sabrina Carpenter           5              -1               -2
# ...                       ...         ...             ...              ...
# 17779   Morgan Wallen, ERNEST          30               2                0
# 17780  Marshmello, Kane Brown          31              -1                1
# 17781              Zach Bryan          32              -1                2
# 17782            Benson Boone          33               0               -5
# 17783                  *NSYNC          34               0               -5
#
#       country snapshot_date  popularity is_explicit  ...  key loudness mode  \
# 0         NaN    2024-08-26        91.0       False  ...  6.0   -7.777  0.0
# 1         NaN    2024-08-26       100.0       False  ...  2.0  -10.171  1.0
# 2         NaN    2024-08-26        94.0       False  ...  0.0   -3.743  0.0
# 3         NaN    2024-08-26        97.0        True  ...  9.0   -6.073  1.0
# 4         NaN    2024-08-26        98.0        True  ...  0.0   -5.478  1.0
# ...       ...           ...         ...         ...  ...  ...      ...  ...
# 17779      CA    2024-08-22        86.0       False  ...  8.0   -3.777  1.0
# 17780      CA    2024-08-22        85.0       False  ...  5.0   -4.752  1.0
# 17781      CA    2024-08-22        86.0       False  ...  7.0   -6.886  1.0
# 17782      CA    2024-08-22        89.0       False  ...  8.0   -4.682  1.0
# 17783      CA    2024-08-22         NaN         NaN  ...  NaN      NaN  NaN
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0304       0.30800          0.000000    0.1220    0.535
# 1           0.0358       0.20000          0.060800    0.1170    0.438
# 2           0.0320       0.00289          0.000000    0.1930    0.838
# 3           0.0540       0.27400          0.000000    0.1040    0.579
# 4           0.0285       0.10700          0.000065    0.1850    0.690
# ...            ...           ...               ...       ...      ...
# 17779       0.0361       0.21600          0.000009    0.1650    0.399
# 17780       0.0472       0.00537          0.000000    0.5490    0.785
# 17781       0.0288       0.22700          0.000085    0.0693    0.435
# 17782       0.0687       0.17400          0.000000    0.0933    0.544
# 17783          NaN           NaN               NaN       NaN      NaN
#
#          tempo  time_signature
# 0      157.969             3.0
# 1      104.978             4.0
# 2      116.034             4.0
# 3      107.071             4.0
# 4      103.969             4.0
# ...        ...             ...
# 17779  172.037             4.0
# 17780  129.963             4.0
# 17781   80.868             3.0
# 17782  181.489             4.0
# 17783      NaN             NaN
#
# [17784 rows x 25 columns]

# %%
data_song_properties = data.drop(["artists", "daily_rank", "daily_movement", "weekly_movement", "country", "album_name", "album_release_date"], axis=1)
data_song_properties.head()
# Out:
#                spotify_id                  name snapshot_date  popularity  \
# 0  2plbrEY59IikOBgBGLjaoe      Die With A Smile    2024-08-26        91.0
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER    2024-08-26       100.0
# 2  7tI8dRuH2Yc6RuoTjxo4dU                   Who    2024-08-26        94.0
# 3  5N3hjp1WNayUPZrA8kJmJP  Please Please Please    2024-08-26        97.0
# 4  2qSkIjg1o9h3YT9RAgYN75              Espresso    2024-08-26        98.0
#
#   is_explicit  duration_ms  danceability  energy  key  loudness  mode  \
# 0       False     251667.0         0.521   0.592  6.0    -7.777   0.0
# 1       False     210373.0         0.747   0.507  2.0   -10.171   1.0
# 2       False     170887.0         0.660   0.756  0.0    -3.743   0.0
# 3        True     186365.0         0.669   0.586  9.0    -6.073   1.0
# 4        True     175459.0         0.701   0.760  0.0    -5.478   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0304       0.30800          0.000000     0.122    0.535  157.969
# 1       0.0358       0.20000          0.060800     0.117    0.438  104.978
# 2       0.0320       0.00289          0.000000     0.193    0.838  116.034
# 3       0.0540       0.27400          0.000000     0.104    0.579  107.071
# 4       0.0285       0.10700          0.000065     0.185    0.690  103.969
#
#    time_signature
# 0             3.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
data_song_properties_latest = data_song_properties.drop_duplicates(subset=['spotify_id'], keep='first')
data_song_properties_latest.head()
# Out:
#                spotify_id                  name snapshot_date  popularity  \
# 0  2plbrEY59IikOBgBGLjaoe      Die With A Smile    2024-08-26        91.0
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER    2024-08-26       100.0
# 2  7tI8dRuH2Yc6RuoTjxo4dU                   Who    2024-08-26        94.0
# 3  5N3hjp1WNayUPZrA8kJmJP  Please Please Please    2024-08-26        97.0
# 4  2qSkIjg1o9h3YT9RAgYN75              Espresso    2024-08-26        98.0
#
#   is_explicit  duration_ms  danceability  energy  key  loudness  mode  \
# 0       False     251667.0         0.521   0.592  6.0    -7.777   0.0
# 1       False     210373.0         0.747   0.507  2.0   -10.171   1.0
# 2       False     170887.0         0.660   0.756  0.0    -3.743   0.0
# 3        True     186365.0         0.669   0.586  9.0    -6.073   1.0
# 4        True     175459.0         0.701   0.760  0.0    -5.478   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0304       0.30800          0.000000     0.122    0.535  157.969
# 1       0.0358       0.20000          0.060800     0.117    0.438  104.978
# 2       0.0320       0.00289          0.000000     0.193    0.838  116.034
# 3       0.0540       0.27400          0.000000     0.104    0.579  107.071
# 4       0.0285       0.10700          0.000065     0.185    0.690  103.969
#
#    time_signature
# 0             3.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
data_song_details = data.drop(["popularity", "is_explicit", "duration_ms", "danceability", "energy", "key", "loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "time_signature"], axis=1)
data_song_details.head()
# Out:
#                spotify_id                  name                artists  \
# 0  2plbrEY59IikOBgBGLjaoe      Die With A Smile  Lady Gaga, Bruno Mars
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER          Billie Eilish
# 2  7tI8dRuH2Yc6RuoTjxo4dU                   Who                  Jimin
# 3  5N3hjp1WNayUPZrA8kJmJP  Please Please Please      Sabrina Carpenter
# 4  2qSkIjg1o9h3YT9RAgYN75              Espresso      Sabrina Carpenter
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               1                6     NaN    2024-08-26
# 1           2              -1                0     NaN    2024-08-26
# 2           3               2               -2     NaN    2024-08-26
# 3           4              -1                0     NaN    2024-08-26
# 4           5              -1               -2     NaN    2024-08-26
#
#              album_name album_release_date
# 0      Die With A Smile         2024-08-16
# 1  HIT ME HARD AND SOFT         2024-05-17
# 2                  MUSE         2024-07-19
# 3  Please Please Please         2024-06-06
# 4              Espresso         2024-04-12

# %%
data_song_properties_latest.to_parquet('song_properties.parquet', index=True)
data_song_details.to_parquet('song_rankings.parquet', index=True)
