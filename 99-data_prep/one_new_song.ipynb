# %%
import pandas as pd

# %%
current_songs = pd.read_parquet("song_properties.parquet")

# %%
current_songs
# Out:
#                      spotify_id  \
# 1132002  59NraMJsLaMCVtwXTSia8i
# 1129581  6wf7Yu7cxBSPrRlWeSeK0Q
# 1129580  0QZ5yyl6B6utIWkxeBDxQN
# 1129579  2YSzYUF3jWqb9YP9VXmpjE
# 1129578  1aILoZDz3wsIKO4Nj6aLgz
# ...                         ...
# 1997     3APdIdF8H0jsxSuGOqXedS
# 1944     2s48bwi9I2aueqJ7S5lYfw
# 2530     7meQV8OcOf9ZWYpK01JOqk
# 2536     1LnIYqWfeWlDE78xA7yhBP
# 2720     50qm2o9IDiRpn62f3NMzw8
#
#                                                       name  \
# 1132002                                              Prada
# 1129581  What Was I Made For? [From The Motion Picture ...
# 1129580                                   The Night We Met
# 1129579                                 IDGAF (feat. Yeat)
# 1129578                            ER DETTE TIL Å OVERLEVE
# ...                                                    ...
# 1997                                     Kabhi Kabhi Aditi
# 1944                                                 S.O.S
# ...

# %%
new_songs = pd.read_csv("universal_top_spotify_songs.csv")

# %%
diff = new_songs[~new_songs["spotify_id"].isin(current_songs["spotify_id"])]
diff
# Out:
#                     spotify_id                                   name  \
# 1       2CGNAOSuO1MEFCbBRgUzjd                      luther (with sza)
# 4       4wJ5Qq0jBN4ajy7ouZIV1c                                   APT.
# 6       0aB0v4027ukVziUGwVGYpG           tv off (feat. lefty gunplay)
# 7       3sK8wGT43QFpWrvNQsrQya                                   DtMF
# 8       5ZLUm9eab8y3tqQ1OhQSHI                            Abracadabra
# ...                        ...                                    ...
# 577127  0UvCh63URrLFcPkKt99hHd  Don't Look Back in Anger - Remastered
# 577129  1D2SVYXZdtNfJCg8wZWvVz                           Live Forever
# 577588  5CeN3nUDe06TeC8TdZ62EY                           Lamine Yamal
# 577590  47KhhDku9RLDsWIJjYaXDs                       Around The World
# 578085  3lj4Jt7n9k6wlsgTz6ruyV                            DJALEBIBEBI
#
#                               artists  daily_rank  daily_movement  \
# ...

# %%
favorite_new_song = "1D2SVYXZdtNfJCg8wZWvVz" #Live Forever from Oasis
fav_new_song_properties = pd.DataFrame(new_songs[new_songs["spotify_id"]==favorite_new_song].iloc[0][current_songs.columns]).T
fav_new_song_properties["snapshot_date"] = pd.to_datetime(fav_new_song_properties["snapshot_date"])
fav_new_song_properties
# Out:
#                     spotify_id          name artists snapshot_date  \
# 522374  1D2SVYXZdtNfJCg8wZWvVz  Live Forever   Oasis    2024-09-11
#
#        is_explicit duration_ms danceability energy key loudness mode  \
# 522374       False      276826        0.147  0.782   9   -5.393    0
#
#        speechiness acousticness instrumentalness liveness valence   tempo  \
# 522374      0.0367     0.000014         0.000007    0.369   0.182  90.896
#
#        time_signature
# 522374              4

# %%
# current_songs_plus_one = pd.concat([current_songs, fav_new_song_properties], ignore_index=True)
# current_songs_plus_one
# Out:
#                    spotify_id  \
# 0      59NraMJsLaMCVtwXTSia8i
# 1      6wf7Yu7cxBSPrRlWeSeK0Q
# 2      0QZ5yyl6B6utIWkxeBDxQN
# 3      2YSzYUF3jWqb9YP9VXmpjE
# 4      1aILoZDz3wsIKO4Nj6aLgz
# ...                       ...
# 14241  2s48bwi9I2aueqJ7S5lYfw
# 14242  7meQV8OcOf9ZWYpK01JOqk
# 14243  1LnIYqWfeWlDE78xA7yhBP
# 14244  50qm2o9IDiRpn62f3NMzw8
# 14245  1D2SVYXZdtNfJCg8wZWvVz
#
#                                                     name  \
# 0                                                  Prada
# 1      What Was I Made For? [From The Motion Picture ...
# 2                                       The Night We Met
# 3                                     IDGAF (feat. Yeat)
# 4                                ER DETTE TIL Å OVERLEVE
# ...                                                  ...
# 14241                                              S.O.S
# 14242                                          Joku raja
# 14243                              Oo siellä jossain mun
# ...

# %%
# current_songs_plus_one[~current_songs_plus_one["spotify_id"].isin(current_songs["spotify_id"])]
# Out:
#                    spotify_id          name artists snapshot_date is_explicit  \
# 14245  1D2SVYXZdtNfJCg8wZWvVz  Live Forever   Oasis    2024-09-11       False
#
#       duration_ms danceability energy key loudness mode speechiness  \
# 14245      276826        0.147  0.782   9   -5.393    0      0.0367
#
#       acousticness instrumentalness liveness valence   tempo time_signature
# 14245     0.000014         0.000007    0.369   0.182  90.896              4

# %%
fav_new_song_properties.to_parquet('song_properties_plus_one.parquet', index=True)
