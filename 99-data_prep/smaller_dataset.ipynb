# %%
import pandas as pd

# %%
full_dataset = pd.read_parquet("song_properties.parquet")

# %%
full_dataset
# Out:
#                      spotify_id  \
# 1132002  59NraMJsLaMCVtwXTSia8i
# 1129581  6wf7Yu7cxBSPrRlWeSeK0Q
# 1129580  0QZ5yyl6B6utIWkxeBDxQN
# 1129579  2YSzYUF3jWqb9YP9VXmpjE
# 1129578  1aILoZDz3wsIKO4Nj6aLgz
# ...                         ...
# 1997     3APdIdF8H0jsxSuGOqXedS
# 1944     2s48bwi9I2aueqJ7S5lYfw
# 2530     7meQV8OcOf9ZWYpK01JOqk
# 2536     1LnIYqWfeWlDE78xA7yhBP
# 2720     50qm2o9IDiRpn62f3NMzw8
#
#                                                       name  \
# 1132002                                              Prada
# 1129581  What Was I Made For? [From The Motion Picture ...
# 1129580                                   The Night We Met
# 1129579                                 IDGAF (feat. Yeat)
# 1129578                            ER DETTE TIL Å OVERLEVE
# ...                                                    ...
# 1997                                     Kabhi Kabhi Aditi
# 1944                                                 S.O.S
# ...

# %%
small_dataset = full_dataset[:5000]
small_dataset
# Out:
#                      spotify_id  \
# 1132002  59NraMJsLaMCVtwXTSia8i
# 1129581  6wf7Yu7cxBSPrRlWeSeK0Q
# 1129580  0QZ5yyl6B6utIWkxeBDxQN
# 1129579  2YSzYUF3jWqb9YP9VXmpjE
# 1129578  1aILoZDz3wsIKO4Nj6aLgz
# ...                         ...
# 877151   6F5AF74ea4QZz3cSFBnYXJ
# 877150   1UBZ1Lv34lqXEy62vMNGXB
# 877166   5IkUQ5XQ2VfJODo6ZiYed7
# 877760   7txb4BYsSxE9wZ2RxFucPy
# 877756   6jinEAvpeFUuXTQLVwb9mN
#
#                                                       name  \
# 1132002                                              Prada
# 1129581  What Was I Made For? [From The Motion Picture ...
# 1129580                                   The Night We Met
# 1129579                                 IDGAF (feat. Yeat)
# 1129578                            ER DETTE TIL Å OVERLEVE
# ...                                                    ...
# 877151                                      Sentir Zuliano
# 877150                                La Voy a Tocar a Pie
# ...

# %%
small_dataset.to_parquet('small_song_properties.parquet', index=True)
